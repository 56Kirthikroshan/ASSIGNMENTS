# %% [markdown]
# Data Structures, Functions, Numpy & Pandas

# %% [markdown]
# Section A: Data Structures & Control Structures

# %% [markdown]
# Q.1)

# %%
lst=[10,20,30,40,50]
lst.append(60)
lst
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
lst.extend([70,80])

# %%
lst
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
lst.insert(99,4)

# %%
lst
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 4]

# %%
lst.pop()
# Out:
# 4

# %%
lst.pop(4)
lst
# Out:
# [10, 20, 30, 40, 60, 70, 80]

# %%
lst.insert(3,5)
lst
# Out:
# [10, 20, 30, 5, 40, 60, 70, 80]

# %%
lst.index(60)
# Out:
# 5

# %%
lst.count(10)
lst
# Out:
# [10, 20, 30, 5, 40, 60, 70, 80]

# %%
lst.sort()
lst
# Out:
# [5, 10, 20, 30, 40, 60, 70, 80]

# %%
lst.sort(reverse=True)
lst
# Out:
# [80, 70, 60, 40, 30, 20, 10, 5]

# %%
lst.remove(10)
lst
# Out:
# [80, 70, 60, 40, 30, 20, 5]

# %%
lst.clear()
lst
# Out:
# []

# %% [markdown]
# Q.2)

# %%
tupl=("Ram","Tom","Sam")
tupl[1]="kiran"  
#### tuple is immutable : the values once assigned cant be changed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 tupl=("Ram","Tom","Sam")
# ----> 2 tupl[1]="kiran"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Q.3)

# %%
setss={1,2,2,2,3,3,4,4,5}
print(setss) 
#### set which allows only the unique values and it does not allow duplicate values
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Q.4)

# %%
dict={'name':"Ram",'age':18,'city':"bangalore"}
dict['age']=21
dict['email']='kros@gmail.com'

# %%
dict
# Out:
# {'name': 'Ram', 'age': 21, 'city': 'bangalore', 'email': 'kros@gmail.com'}

# %% [markdown]
# Q.5)

# %%
age=int(input("enter the age:"))
if (age<18):
    print("Not eligible to vote")
else:
    print("eligible to vote")
# Out:
# enter the age: 18
# eligible to vote

# %% [markdown]
# Q.6)

# %%
marks=int(input("Enter the marks:"))
if marks>=90:
    print("grade A")
elif marks>=75 and marks<=89:
    print("grade B")
elif marks>=50 and marks<=74:
    print("grade C")
else:
    print("Fail")
# Out:
# Enter the marks: 65
# grade C

# %% [markdown]
# Q.7)

# %%
n=int(input("Enter the no:"))
if n>0 and n%2==0:
    print("positive and even no")
elif n==0:
    print("zero")
else:
    print("negative and odd no")
# Out:
# Enter the no: 3
# negative and odd no

# %% [markdown]
# Section B: Numpy

# %% [markdown]
# Q.8)

# %%
import numpy as np
scaler=np.array(5)
scaler
# Out:
# array(5)

# %%
arr1=np.array([1,2,3,4,5])
print("arr1:",arr1)
# Out:
# arr1: [1 2 3 4 5]

# %%
arr2=np.array([[10,20,30],[40,50,60]])
print("arr2:",arr2)
# Out:
# arr2: [[10 20 30]
#  [40 50 60]]

# %% [markdown]
# Q.9)

# %%
rand_array=np.random.randint(0,100,(4,4))
print(rand_array)
# Out:
# [[59 36  5 53]
#  [73 26 73  2]
#  [34 52 66 69]
#  [37  1 94 19]]

# %% [markdown]
# Q.10)

# %%
import pandas as pd
arr3=np.array([[10,11,12],[13,14,15],[16,17,18]])
print(arr3)
df=pd.DataFrame(arr3,columns=['A','B','C'])
df
# Out:
# [[10 11 12]
#  [13 14 15]
#  [16 17 18]]
#     A   B   C
# 0  10  11  12
# 1  13  14  15
# 2  16  17  18

# %% [markdown]
# Section C: Exploring Pandas

# %% [markdown]
# Q.11)

# %%
data={"Name": ["Amit", "Riya", "John", "Neha", "Arun",
             "Riya", "Sita", "Karan", "Meena", "Amit"],
    "Age": [25, 22, 28, 24, 30, 22, 27, 26, 29, 25],
    "City": ["Delhi", "Mumbai", "Chennai", "Delhi", "Pune",
             "Mumbai", "Kolkata", "Bangalore", "Delhi", "Delhi"],
    "Salary": [40000, 35000, 50000, 42000, 25000,
               35000, 48000, 45000, 52000, 40000]}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age       City  Salary
# 0   Amit   25      Delhi   40000
# 1   Riya   22     Mumbai   35000
# 2   John   28    Chennai   50000
# 3   Neha   24      Delhi   42000
# 4   Arun   30       Pune   25000
# 5   Riya   22     Mumbai   35000
# 6   Sita   27    Kolkata   48000
# 7  Karan   26  Bangalore   45000
# 8  Meena   29      Delhi   52000
# 9   Amit   25      Delhi   40000

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes
#              Age        Salary
# count  10.000000     10.000000
# mean   25.800000  41200.000000
# std     2.740641   8148.619515
# min    22.000000  25000.000000
# 25%    24.250000  36250.000000
# 50%    25.500000  41000.000000
# 75%    27.750000  47250.000000
# max    30.000000  52000.000000

# %%
print(df['Name'],df['City'])
# Out:
# 0     Amit
# 1     Riya
# 2     John
# 3     Neha
# 4     Arun
# 5     Riya
# 6     Sita
# 7    Karan
# 8    Meena
# 9     Amit
# Name: Name, dtype: object 0        Delhi
# 1       Mumbai
# 2      Chennai
# 3        Delhi
# 4         Pune
# 5       Mumbai
# 6      Kolkata
# 7    Bangalore
# 8        Delhi
# 9        Delhi
# Name: City, dtype: object

# %%
df.drop('City',axis=1)
# Out:
#     Name  Age  Salary
# 0   Amit   25   40000
# 1   Riya   22   35000
# 2   John   28   50000
# 3   Neha   24   42000
# 4   Arun   30   25000
# 5   Riya   22   35000
# 6   Sita   27   48000
# 7  Karan   26   45000
# 8  Meena   29   52000
# 9   Amit   25   40000

# %%
df['Salary']=df['Salary'].fillna(df['Salary']).mean()
df
# Out:
#     Name  Age       City   Salary
# 0   Amit   25      Delhi  41200.0
# 1   Riya   22     Mumbai  41200.0
# 2   John   28    Chennai  41200.0
# 3   Neha   24      Delhi  41200.0
# 4   Arun   30       Pune  41200.0
# 5   Riya   22     Mumbai  41200.0
# 6   Sita   27    Kolkata  41200.0
# 7  Karan   26  Bangalore  41200.0
# 8  Meena   29      Delhi  41200.0
# 9   Amit   25      Delhi  41200.0

# %%
df.drop_duplicates()
# Out:
#     Name  Age       City   Salary
# 0   Amit   25      Delhi  41200.0
# 1   Riya   22     Mumbai  41200.0
# 2   John   28    Chennai  41200.0
# 3   Neha   24      Delhi  41200.0
# 4   Arun   30       Pune  41200.0
# 6   Sita   27    Kolkata  41200.0
# 7  Karan   26  Bangalore  41200.0
# 8  Meena   29      Delhi  41200.0
